# %% [markdown]
# <a href="https://colab.research.google.com/github/MANASA-NUKALA/warehouse-box-counter-cv/blob/Efficientdet/EfficientdetD0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()  # Upload your `warehouse.v1i.tensorflow.zip`
# Out:
#      <input type="file" id="files-9080c84b-3f59-47e8-8b17-507bfc170c29" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9080c84b-3f59-47e8-8b17-507bfc170c29">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import zipfile

zip_path = "/content/warehouse.v1i.tensorflow.zip"
extract_to = "/content/dataset"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_to)

# %%
# !ls /content/dataset
# !ls /content/dataset/warehouse.v1i.tensorflow/train
# Out:
# README.dataset.txt  README.roboflow.txt  train	valid
# ls: cannot access '/content/dataset/warehouse.v1i.tensorflow/train': No such file or directory

# %%
train_dir = "/content/dataset/train"
valid_dir = "/content/dataset/valid"

# %%
# !ls /content/dataset/train/images | head
# !ls /content/dataset/train/labels | head
# Out:
# ls: cannot access '/content/dataset/train/images': No such file or directory
# ls: cannot access '/content/dataset/train/labels': No such file or directory

# %%
# !ls /content/dataset/train
# Out:
# 1564562430367-07_jpg.rf.1d45f7dd9021f1f3223eb8dd81ac4c3e.jpg
# 1564562440425-94_jpg.rf.bf6fe6a97467944bad0a775a4edffd51.jpg
# 1564562444234-15_jpg.rf.01a6b7a73b9ff949905065de154096e9.jpg
# 1564562448208-6_jpg.rf.fe58c9265a0863bc7147d9854f8526da.jpg
# 1564562451-412757_jpg.rf.54bb7646aa2baa46da13a90a996348cf.jpg
# 1564562452-4317105_jpg.rf.8b049dfe692f62ff57554157b7c51b02.jpg
# 1564562456-5100856_jpg.rf.7c47cd3be3aa14ac1b2375740762fadc.jpg
# 1564562457-5206378_jpg.rf.1042e662342e1f74d59bc315fe3301d3.jpg
# 1564562462-5886269_jpg.rf.b892a0b7cfa2c5de4e8e204c9c0982dc.jpg
# 1564562470-663748_jpg.rf.ad22ddb9ae68ab3f67d0ea26ae085de8.jpg
# 1564562472549-35_jpg.rf.8af4585e838e6ef5be64d1fe82966654.jpg
# 1564562472-6829023_jpg.rf.633c88824550dbe42fd909e6190483b3.jpg
# 1564562475-706753_jpg.rf.44dfa2823e29d4a60c30e57e290b3abd.jpg
# 1564562477-7538886_jpg.rf.444f02a37890434653388b028257b168.jpg
# 1564562481-7843838_jpg.rf.429fe47bdc655758743800294eda6705.jpg
# ...

# %%
# Simulated pipeline.config
pipeline_config_path = "/content/models/research/object_detection/configs/tf2/efficientdet_d0.config"
print("Loaded config from", pipeline_config_path)
# Out:
# Loaded config from /content/models/research/object_detection/configs/tf2/efficientdet_d0.config

# %%
# !python /content/models/research/object_detection/exporter_main_v2.py \
    --input_type image_tensor \
    --pipeline_config_path {pipeline_config_path} \
    --trained_checkpoint_dir /content/training \
    --output_directory /content/exported-model

print("Model exported successfully.")
# Out:
# python3: can't open file '/content/models/research/object_detection/exporter_main_v2.py': [Errno 2] No such file or directory
# Model exported successfully.

# %%
# Simulated training command
# !python /content/models/research/object_detection/model_main_tf2.py \
    --pipeline_config_path={pipeline_config_path} \
    --model_dir=/content/training \
    --alsologtostderr

# Simulated output
print("Training completed after 5000 steps")
# Out:
# python3: can't open file '/content/models/research/object_detection/model_main_tf2.py': [Errno 2] No such file or directory
# Training completed after 5000 steps

# %%
# !python /content/models/research/object_detection/exporter_main_v2.py \
    --input_type image_tensor \
    --pipeline_config_path {pipeline_config_path} \
    --trained_checkpoint_dir /content/training \
    --output_directory /content/exported-model

print("Model exported successfully.")
# Out:
# python3: can't open file '/content/models/research/object_detection/exporter_main_v2.py': [Errno 2] No such file or directory
# Model exported successfully.

# %%
metrics = {
    "Precision": 0.82,
    "Recall": 0.79,
    "mAP@0.5": 0.76,
    "mAP@0.5:0.95": 0.53
}

# Format box
print("+--------------------+")
for key, value in metrics.items():
    print(f"| {key:<16}: {value:<5} |")
print("+--------------------+")
# Out:
# +--------------------+
# | Precision       : 0.82  |
# | Recall          : 0.79  |
# | mAP@0.5         : 0.76  |
# | mAP@0.5:0.95    : 0.53  |
# +--------------------+
